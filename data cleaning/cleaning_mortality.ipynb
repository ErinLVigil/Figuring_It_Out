# %%
import pandas as pd

mortality_df = pd.read_csv('Heart_Disease_Mortality_Data.csv')

mortality_df.head()
# Out:
#    Year LocationAbbr    LocationDesc GeographicLevel DataSource  \
# 0  2014           AK  Aleutians East          County       NVSS
# 1  2014           AK  Aleutians West          County       NVSS
# 2  2014           AK       Anchorage          County       NVSS
# 3  2014           AK          Bethel          County       NVSS
# 4  2014           AK     Bristol Bay          County       NVSS
#
#                      Class                    Topic  Data_Value  \
# 0  Cardiovascular Diseases  Heart Disease Mortality       105.3
# 1  Cardiovascular Diseases  Heart Disease Mortality       211.9
# 2  Cardiovascular Diseases  Heart Disease Mortality       257.9
# 3  Cardiovascular Diseases  Heart Disease Mortality       351.6
# 4  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#           Data_Value_Unit                                    Data_Value_Type  \
# 0  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# ...

# %%
mortality2_df = mortality_df.drop(columns=['DataSource', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'LocationID', 'Location 1'])

# %%
mortality2_df.dropna(how='any')
# Out:
#        Year LocationAbbr      LocationDesc GeographicLevel  \
# 0      2014           AK    Aleutians East          County
# 1      2014           AK    Aleutians West          County
# 2      2014           AK         Anchorage          County
# 3      2014           AK            Bethel          County
# 5      2014           AK            Denali          County
# ...     ...          ...               ...             ...
# 59055  2014           KS   Sedgwick County          County
# 59059  2014           TX  Galveston County          County
# 59062  2014           MT     Fergus County          County
# 59063  2014           TX     Travis County          County
# 59067  2014           NJ     Mercer County          County
#
#                          Class                    Topic  Data_Value  \
# 0      Cardiovascular Diseases  Heart Disease Mortality       105.3
# 1      Cardiovascular Diseases  Heart Disease Mortality       211.9
# ...

# %%
mortality3_df= mortality2_df.loc[(mortality2_df['Stratification1'] == 'Overall') & (mortality2_df['Stratification2'] == 'Overall')]

# %%
mortality3_df.count()
# Out:
# Year                       3282
# LocationAbbr               3282
# LocationDesc               3282
# GeographicLevel            3282
# Class                      3282
# Topic                      3282
# Data_Value                 3274
# Data_Value_Unit            3282
# Data_Value_Type            3282
# StratificationCategory1    3282
# Stratification1            3282
# StratificationCategory2    3282
# Stratification2            3282
# TopicID                    3282
# dtype: int64

# %%
mortality3_df['Data_Value'].value_counts()
# Out:
# 358.6    7
# 361.1    6
# 347.3    6
# 349.4    6
# 343.5    6
#         ..
# 380.2    1
# 486.6    1
# 541.3    1
# 554.9    1
# 302.8    1
# Name: Data_Value, Length: 2014, dtype: int64

# %%
mortality3_df.to_csv('mortality2.csv', index=False)
