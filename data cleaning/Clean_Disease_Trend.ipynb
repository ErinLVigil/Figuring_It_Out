# %%
import pandas as pd

trends_df = pd.read_csv("clean_disease_trends_file.csv")

trends_df
# Out:
#       Unnamed: 0         Year LocationAbbr LocationDesc GeographicLevel  \
# 0        5268646  2010 - 2019           AL      Autauga          County
# 1        5268648  1999 - 2010           AL      Autauga          County
# 2        5268650  1999 - 2010           AL      Autauga          County
# 3        5268652  1999 - 2010           AL      Autauga          County
# 4        5268654  2010 - 2019           AL      Autauga          County
# ...          ...          ...          ...          ...             ...
# 8995     5770231  2010 - 2019           WY       Weston          County
# 8996     5770233  1999 - 2010           WY       Weston          County
# 8997     5770235  1999 - 2010           WY       Weston          County
# 8998     5770237  1999 - 2010           WY       Weston          County
# 8999     5770239  2010 - 2019           WY       Weston          County
#
#      DataSource                    Class                         Topic  \
# ...

# %%
trends2_df = trends_df.drop(columns=['LocationAbbr', 'GeographicLevel','DataSource', 'Data_Value_Footnote', 'Confidence_limit_Low', 'Confidence_limit_High'])

trends2_df
# Out:
#       Unnamed: 0         Year LocationDesc                    Class  \
# 0        5268646  2010 - 2019      Autauga  Cardiovascular Diseases
# 1        5268648  1999 - 2010      Autauga  Cardiovascular Diseases
# 2        5268650  1999 - 2010      Autauga  Cardiovascular Diseases
# 3        5268652  1999 - 2010      Autauga  Cardiovascular Diseases
# 4        5268654  2010 - 2019      Autauga  Cardiovascular Diseases
# ...          ...          ...          ...                      ...
# 8995     5770231  2010 - 2019       Weston  Cardiovascular Diseases
# 8996     5770233  1999 - 2010       Weston  Cardiovascular Diseases
# 8997     5770235  1999 - 2010       Weston  Cardiovascular Diseases
# 8998     5770237  1999 - 2010       Weston  Cardiovascular Diseases
# 8999     5770239  2010 - 2019       Weston  Cardiovascular Diseases
#
#                              Topic  Data_Value Data_Value_Unit  \
# 0                All heart disease       -17.2               %
# ...

# %%
trends2_df.drop(columns=trends_df.columns[:1],axis=1, inplace=True)
trends2_df
# Out:
#              Year LocationDesc                    Class  \
# 0     2010 - 2019      Autauga  Cardiovascular Diseases
# 1     1999 - 2010      Autauga  Cardiovascular Diseases
# 2     1999 - 2010      Autauga  Cardiovascular Diseases
# 3     1999 - 2010      Autauga  Cardiovascular Diseases
# 4     2010 - 2019      Autauga  Cardiovascular Diseases
# ...           ...          ...                      ...
# 8995  2010 - 2019       Weston  Cardiovascular Diseases
# 8996  1999 - 2010       Weston  Cardiovascular Diseases
# 8997  1999 - 2010       Weston  Cardiovascular Diseases
# 8998  1999 - 2010       Weston  Cardiovascular Diseases
# 8999  2010 - 2019       Weston  Cardiovascular Diseases
#
#                              Topic  Data_Value Data_Value_Unit  \
# 0                All heart disease       -17.2               %
# 1                       All stroke       -36.7               %
# 2     Coronary heart disease (CHD)       -41.4               %
# ...

# %%
trends2_df['Data_Value_Type'].value_counts()
# Out:
# Total percent change    9000
# Name: Data_Value_Type, dtype: int64

# %%
trends3_df =trends2_df.drop(columns=['Data_Value_Type', 'Data_Value_Footnote_Symbol'])

trends3_df
# Out:
#              Year LocationDesc                    Class  \
# 0     2010 - 2019      Autauga  Cardiovascular Diseases
# 1     1999 - 2010      Autauga  Cardiovascular Diseases
# 2     1999 - 2010      Autauga  Cardiovascular Diseases
# 3     1999 - 2010      Autauga  Cardiovascular Diseases
# 4     2010 - 2019      Autauga  Cardiovascular Diseases
# ...           ...          ...                      ...
# 8995  2010 - 2019       Weston  Cardiovascular Diseases
# 8996  1999 - 2010       Weston  Cardiovascular Diseases
# 8997  1999 - 2010       Weston  Cardiovascular Diseases
# 8998  1999 - 2010       Weston  Cardiovascular Diseases
# 8999  2010 - 2019       Weston  Cardiovascular Diseases
#
#                              Topic  Data_Value Data_Value_Unit  \
# 0                All heart disease       -17.2               %
# 1                       All stroke       -36.7               %
# 2     Coronary heart disease (CHD)       -41.4               %
# ...

# %%
trends3_df['Stratification1'].value_counts()
# Out:
# Ages 65 years and older    8790
# Ages 35-64 years            210
# Name: Stratification1, dtype: int64

# %%
trends3_df['Stratification2'].value_counts()
# Out:
# White                     8690
# Overall                    210
# Hispanic                    85
# Black (Non-Hispanic)        10
# Asian/Pacific Islander       5
# Name: Stratification2, dtype: int64

# %%
trends3_df['LocationDesc'].value_counts()
# Out:
# Autauga    5
# Maury      5
# Blount     5
# Bledsoe    5
# Ziebach    5
#           ..
# Kanabec    5
# Itasca     5
# Isanti     5
# Hubbard    5
# Weston     5
# Name: LocationDesc, Length: 1800, dtype: int64

# %%
trends3_df.to_csv('clean_trend_file.csv', index=False)
