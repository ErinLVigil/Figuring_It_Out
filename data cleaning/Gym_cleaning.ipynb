# %%
import pandas as pd

gyms_df = pd.read_csv("7991.csv")
gyms_df
# Out:
#                          Company Name                      Address  \
# 0                      Powerhouse Gym               802 Gambell St
# 1                     Mountain's Edge                1 Trappers St
# 2                         Alaska Club        701 W 8th Ave Ste 180
# 3                         Alaska Club  1400 W Northern Lights Blvd
# 4                         Alaska Club       747 Old Richardson Hwy
# ...                               ...                          ...
# 88505       Escape Day Spa & Boutique        617 Broadway St Ste C
# 88506       Reincarnation Medical Spa           220 E Broadway Ave
# 88507           Pilates In The Tetons       3525 N Moose Wilson Rd
# 88508                        Gamefish         7710 Granite Loop Rd
# 88509  Spur Restaurant & Bar At Teton                 3385 Cody Ln
#
#                 City State         Zip                County         Phone  \
# 0          Anchorage    AK  99501-3757             Anchorage  9.072777e+09
# ...

# %%
gyms_df = gyms_df.drop_duplicates(subset='Address', keep="first")
gyms_df
# Out:
#                          Company Name                      Address  \
# 0                      Powerhouse Gym               802 Gambell St
# 1                     Mountain's Edge                1 Trappers St
# 2                         Alaska Club        701 W 8th Ave Ste 180
# 3                         Alaska Club  1400 W Northern Lights Blvd
# 4                         Alaska Club       747 Old Richardson Hwy
# ...                               ...                          ...
# 88503               Cocoon Health Spa           1012 Sprucewood Dr
# 88504                 Anytime Fitness                1948 Edgar St
# 88505       Escape Day Spa & Boutique        617 Broadway St Ste C
# 88508                        Gamefish         7710 Granite Loop Rd
# 88509  Spur Restaurant & Bar At Teton                 3385 Cody Ln
#
#                 City State         Zip                County         Phone  \
# 0          Anchorage    AK  99501-3757             Anchorage  9.072777e+09
# ...

# %%
gyms_df.drop(columns=["Phone","Title", "Contact First", "Contact Last", "Direct Phone", "Email", "Website", "SIC Code"], axis=1, inplace=True)

gyms_df
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                          Company Name                      Address  \
# 0                      Powerhouse Gym               802 Gambell St
# 1                     Mountain's Edge                1 Trappers St
# 2                         Alaska Club        701 W 8th Ave Ste 180
# 3                         Alaska Club  1400 W Northern Lights Blvd
# 4                         Alaska Club       747 Old Richardson Hwy
# ...                               ...                          ...
# 88503               Cocoon Health Spa           1012 Sprucewood Dr
# 88504                 Anytime Fitness                1948 Edgar St
# ...

# %%
gyms_df.count()
# Out:
# Company Name      19111
# Address           19111
# City              19111
# State             19112
# Zip               19111
# County            19107
# Employee Count    16946
# Annual Sales      16946
# Industry          19112
# dtype: int64

# %%
gyms_df= gyms_df.dropna(how='any')

# %%
gyms_df.count()
# Out:
# Company Name      16943
# Address           16943
# City              16943
# State             16943
# Zip               16943
# County            16943
# Employee Count    16943
# Annual Sales      16943
# Industry          16943
# dtype: int64

# %%
gyms_df.dtypes
# Out:
# Company Name      object
# Address           object
# City              object
# State             object
# Zip               object
# County            object
# Employee Count    object
# Annual Sales      object
# Industry          object
# dtype: object

# %%
gyms_df['Annual Sales'].value_counts()
# Out:
# Less Than $500,000            10553
# $500,000 To $1 Million         2132
# $1 To 2.5 Million              1802
# Unknown                        1341
# $2.5 To 5 Million               637
# $5 To 10 Million                262
# $10 To 20 Million               121
# $20 To 50 Million                59
# $100 To 500 Million              13
# $50 To 100 Million                6
# Over $1 Billion                   5
# $500 Million To $1 Billion        1
# $193,926,000                      1
# $127,434,000,000                  1
# $2,589,373,000                    1
# $87,959,167,000                   1
# $4,365,400,000                    1
# $28,303,000                       1
# $478,981,000                      1
# $1,126,947,000                    1
# $225,000                          1
# $5,917,124,000                    1
# $17,050,500,000                   1
# Name: Annual Sales, dtype: int64

# %%
gyms_df['Annual Sales']=gyms_df['Annual Sales'].astype(str)
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x = dict.fromkeys(['$193,926,000 ', '$2,589,373,000 ','$87,959,167,000 ','$4,365,400,000 ','$1,126,947,000 ','$5,917,124,000 ','$17,050,500,000 '], 'Over $1 Billion ')    
gyms_df['Annual Sales'] = gyms_df['Annual Sales'].replace(x)
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x = dict.fromkeys(['$127,434,000,000 ', '$478,981,000 '], '$100 To 500 Million')    
gyms_df['Annual Sales'] = gyms_df['Annual Sales'].replace(x)
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x = dict.fromkeys(['$225,000 '], 'Less Than $500,000 ')    
gyms_df['Annual Sales'] = gyms_df['Annual Sales'].replace(x)
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x = dict.fromkeys(['$28,303,000 '], '$20 To 50 Million ')    
gyms_df['Annual Sales'] = gyms_df['Annual Sales'].replace(x)
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
gyms_df['Annual Sales'].value_counts()
# Out:
# Less Than $500,000            10553
# $500,000 To $1 Million         2132
# $1 To 2.5 Million              1802
# Unknown                        1341
# $2.5 To 5 Million               637
# $5 To 10 Million                262
# $10 To 20 Million               121
# $20 To 50 Million                59
# $100 To 500 Million              15
# Over $1 Billion                   7
# $50 To 100 Million                6
# Over $1 Billion                   5
# Less Than $500,000                1
# $20 To 50 Million                 1
# $500 Million To $1 Billion        1
# Name: Annual Sales, dtype: int64

# %%
gyms_df['Industry'].value_counts()
# Out:
# Fitness & Recreational Sports Centers             6947
# Health Clubs Studios & Gymnasiums                 3489
# Physical Fitness Ct                               2070
# Physical Fitness Facilities                       1528
# Physical Fitness Clubs With Training Equipment     963
# Personal Trainers-Fitness                          371
# Exercise Facilities                                365
# Exercise Salon                                     257
# Health Spas                                        216
# Gymnasiums                                         205
# Health Club                                        148
# Pilates                                            108
# Athletic Club And Gymnasiums, Membership           105
# Spas                                                88
# Sports & Recreation Facilities Program              28
# Aerobic Dance And Exercise Classes                  21
# Weight Reducing Clubs                               18
# ...

# %%
gyms_df['Employee Count'].value_counts()
# Out:
# 1 To 4            8082
# 5 To 9            3419
# 20 To 49          2094
# 10 To 19          1943
# 50 To 99           731
# 100 To 249         458
# Unknown             91
# 250 To 499          78
# 500 To 999          21
# 1,000 To 4,999      10
# 5,000 To 9,999       3
# Over 10,000          2
# 115                  1
# 310                  1
# 242,000              1
# 12,600               1
# 13,000               1
# 9,234                1
# 7,800                1
# 21,700               1
# 4                    1
# 40,909               1
# 21,800               1
# Name: Employee Count, dtype: int64

# %%
gyms_df['Employee Count']=gyms_df['Employee Count'].astype(str)
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x = dict.fromkeys(['1 To 4', '4', '5 To 9'], '1 To 10')    
gyms_df['Employee Count'] = gyms_df['Employee Count'].replace(x)
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x = dict.fromkeys(['13,000', '242,000', '12,600', '21,700','40,909','21,800'], 'Over 10,000')    
gyms_df['Employee Count'] = gyms_df['Employee Count'].replace(x)
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x = dict.fromkeys(['9,234', '7,800'], '5,000 To 9,999')    
gyms_df['Employee Count'] = gyms_df['Employee Count'].replace(x)
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x = dict.fromkeys(['115'], '100 To 249')    
gyms_df['Employee Count'] = gyms_df['Employee Count'].replace(x)
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x = dict.fromkeys(['310'], '250 To 499')    
gyms_df['Employee Count'] = gyms_df['Employee Count'].replace(x)
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
gyms_df['Employee Count'].value_counts()
# Out:
# 1 To 10           11502
# 20 To 49           2094
# 10 To 19           1943
# 50 To 99            731
# 100 To 249          459
# Unknown              91
# 250 To 499           79
# 500 To 999           21
# 1,000 To 4,999       10
# Over 10,000           8
# 5,000 To 9,999        5
# Name: Employee Count, dtype: int64

# %%
gyms_df['Zip']=gyms_df['Zip'].astype(str)
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
gyms_df['Zip1'] = gyms_df['Zip'].str[:5]

gyms_df.head()
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       Company Name                      Address       City State         Zip  \
# 0   Powerhouse Gym               802 Gambell St  Anchorage    AK  99501-3757
# 1  Mountain's Edge                1 Trappers St        Tok    AK       99780
# 2      Alaska Club        701 W 8th Ave Ste 180  Anchorage    AK  99501-3469
# 3      Alaska Club  1400 W Northern Lights Blvd  Anchorage    AK  99503-3615
# 4      Alaska Club       747 Old Richardson Hwy  Fairbanks    AK  99701-7898
#
#                  County Employee Count            Annual Sales  \
# ...

# %%
gyms_df.drop(['Zip'], axis=1, inplace=True)

gyms_df.head()
# Out:
# C:\Users\erinv\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       Company Name                      Address       City State  \
# 0   Powerhouse Gym               802 Gambell St  Anchorage    AK
# 1  Mountain's Edge                1 Trappers St        Tok    AK
# 2      Alaska Club        701 W 8th Ave Ste 180  Anchorage    AK
# 3      Alaska Club  1400 W Northern Lights Blvd  Anchorage    AK
# 4      Alaska Club       747 Old Richardson Hwy  Fairbanks    AK
#
#                  County Employee Count            Annual Sales  \
# 0             Anchorage       20 To 49  $500,000 To $1 Million
# 1   Southeast Fairbanks        1 To 10       $1 To 2.5 Million
# ...

# %%
gyms_df.to_csv('Gyms3_file.csv', index=False)
