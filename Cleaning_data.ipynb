# %%
import pandas as pd
import pandas as pd 
walk_df = pd.read_csv("data/EPA_SmartLocationDatabase_V3_Jan_2021_Final.csv")
walk_df
# Out:
#         OBJECTID       GEOID10       GEOID20  STATEFP  COUNTYFP  TRACTCE  \
# 0              1  4.811300e+11  4.811300e+11       48       113     7825
# 1              2  4.811300e+11  4.811300e+11       48       113     7825
# 2              3  4.811300e+11  4.811300e+11       48       113     7825
# 3              4  4.811300e+11  4.811300e+11       48       113     7824
# 4              5  4.811300e+11  4.811300e+11       48       113     7824
# ...          ...           ...           ...      ...       ...      ...
# 220735    220736  7.803100e+11  7.803100e+11       78        30   961000
# 220736    220737  7.803100e+11  7.803100e+11       78        30   961000
# 220737    220738  7.803100e+11  7.803100e+11       78        30   961000
# 220738    220739  7.803100e+11  7.803100e+11       78        30   960700
# 220739    220740  7.803100e+11  7.803100e+11       78        30   960200
#
#         BLKGRPCE    CSA                  CSA_Name     CBSA  ...         D5DRI  \
# ...

# %%
walk_df.dropna()
# Out:
#         OBJECTID       GEOID10       GEOID20  STATEFP  COUNTYFP  TRACTCE  \
# 0              1  4.811300e+11  4.811300e+11       48       113     7825
# 1              2  4.811300e+11  4.811300e+11       48       113     7825
# 2              3  4.811300e+11  4.811300e+11       48       113     7825
# 3              4  4.811300e+11  4.811300e+11       48       113     7824
# 4              5  4.811300e+11  4.811300e+11       48       113     7824
# ...          ...           ...           ...      ...       ...      ...
# 220646    220647  7.202100e+11  7.202100e+11       72        21    30200
# 220647    220648  7.202100e+11  7.202100e+11       72        21    31401
# 220648    220649  7.202100e+11  7.202100e+11       72        21    31202
# 220649    220650  7.205320e+11  7.205320e+11       72        53   150400
# 220650    220651  7.205320e+11  7.205320e+11       72        53   150104
#
#         BLKGRPCE    CSA                  CSA_Name     CBSA  ...         D5DRI  \
# ...

# %%
new_walk_df= walk_df[['OBJECTID','GEOID10','GEOID20','STATEFP','BLKGRPCE','CSA_Name','TotPop','P_WrkAge',
                            'D2A_Ranked','D2B_Ranked','D3B_Ranked','D4A_Ranked','NatWalkInd']]

# %%
for col in new_walk_df.columns:
    print(col)
# Out:
# OBJECTID
# GEOID10
# GEOID20
# STATEFP
# BLKGRPCE
# CSA_Name
# TotPop
# P_WrkAge
# D2A_Ranked
# D2B_Ranked
# D3B_Ranked
# D4A_Ranked
# NatWalkInd

# %%
new_walk_df.to_csv('walkability_file.csv')

# %%
import pandas as pd

gyms_df = pd.read_csv("7991.csv")
gyms_df
# Out:
#                          Company Name                      Address  \
# 0                      Powerhouse Gym               802 Gambell St
# 1                     Mountain's Edge                1 Trappers St
# 2                         Alaska Club        701 W 8th Ave Ste 180
# 3                         Alaska Club  1400 W Northern Lights Blvd
# 4                         Alaska Club       747 Old Richardson Hwy
# ...                               ...                          ...
# 88505       Escape Day Spa & Boutique        617 Broadway St Ste C
# 88506       Reincarnation Medical Spa           220 E Broadway Ave
# 88507           Pilates In The Tetons       3525 N Moose Wilson Rd
# 88508                        Gamefish         7710 Granite Loop Rd
# 88509  Spur Restaurant & Bar At Teton                 3385 Cody Ln
#
#                 City State         Zip                County         Phone  \
# 0          Anchorage    AK  99501-3757             Anchorage  9.072777e+09
# ...

# %%
gyms_df.to_csv('gym_file.csv')
